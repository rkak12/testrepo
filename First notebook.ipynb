# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Kausar Amin__
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because i love to drill dwon data and predicting values to show in graph.*

# %% [markdown]
# ### My code will show the how to show output in notebook

# %%
print("My Name is Kausar Amin")
# Out:
# My Name is Kausar Amin

# %% [markdown]
# - My List in bullet
#      - First Item
#
# 1. My List in number
#      1. First Item
#
# # to show image
# <img src="C:/cat.gif" alt="to show graphic" title="Title text" />
